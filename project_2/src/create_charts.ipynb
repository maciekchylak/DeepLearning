# %% [markdown]
# ## Create charts for report

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train_acc=[0.37, 0.68, 0.74, 0.79, 0.81, 0.83, 0.84, 0.85, 0.86, 0.87]
test_acc=[0.65, 0.76, 0.78, 0.82, 0.82, 0.85, 0.85,0.85, 0.86, 0.86]

plt.plot(train_acc, label='train')
plt.plot(test_acc, label='test')
plt.legend()
plt.title('Accuracy for best LSTM model')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
train_acc=[0.35, 0.42, 0.37, 0.26, 0.32, 0.37, 0.40]
test_acc=[0.47, 0.49, 0.27, 0.32, 0.36, 0.4, 0.43]

plt.plot(train_acc, label='train')
plt.plot(test_acc, label='test')
plt.legend()
plt.title('Accuracy for best Simple RNN model')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
train_acc=[0.55, 0.79, 0.84, 0.87, 0.89, 0.91, 0.91, 0.92, 0.93, 0.94]
test_acc=[0.76, 0.83, 0.85, 0.87, 0.89, 0.89, 0.90, 0.90, 0.90, 0.90]

plt.plot(train_acc, label='train')
plt.plot(test_acc, label='test')
plt.legend()
plt.title('Accuracy for best GRU model')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6ec8773e-c89e-4114-ab03-f7a026dc9b15' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
